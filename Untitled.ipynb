# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\mayur\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df_same_lang = pd.read_csv(r"C:\Users\mayur\Assignments\CS6120\NLI\raw_data\final_dataset.csv", sep=",")
df_same_lang.head()
# Out:
#                  pair_id annotator_id language lang1 lang2  \
# 0  1636790850_1634135133          NaN       zh    zh    zh
# 1  1604224633_1554313283          NaN       de    de    de
# 2  1630418022_1496780166          NaN       ar    ar    ar
# 3  1517915550_1630951473          NaN       tr    tr    tr
# 4  1528142328_1528224141          NaN       tr    tr    tr
#
#                                               text_a  \
# 0                                 法国医护人员在巴黎示威游行万余人参加
# 1  „Der schwerste Kampf in meinem Leben“: Ministe...
# 2  مصر-  بدء المرحلة الأولى من البرنامج التدريبى ...
# 3          Gökdelenlerin yıkımı havadan görüntülendi
# 4     Yüz nakilli Recep Sert ile Esma Sert boşanıyor
#
#                                               text_b text_source  \
# 0                                   示威者在巴黎共和广场抗议种族歧视  title_only
# 1  Schwesig: Noch immer Touristen in Mecklenburg-...  title_only
# 2  خالد الجندى عن قاعدة برنيس: «أعداء الوطن حالته...  title_only
# ...

# %%
df_same_lang.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15662 entries, 0 to 15661
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   pair_id             15662 non-null  str
#  1   annotator_id        12 non-null     str
#  2   language            15662 non-null  str
#  3   lang1               15662 non-null  str
#  4   lang2               15662 non-null  str
#  5   text_a              15662 non-null  str
#  6   text_b              15662 non-null  str
#  7   text_source         15662 non-null  str
#  8   link1               15662 non-null  str
#  9   link2               15662 non-null  str
#  10  content_similarity  15650 non-null  float64
#  11  GEO                 15662 non-null  float64
#  12  ENT                 15662 non-null  float64
#  13  TIME                15662 non-null  float64
#  14  NAR                 15662 non-null  float64
#  15  OVERALL             15662 non-null  float64
# ...

# %%
grouped_counts = df_same_lang.groupby('source_file').size()
df_counts = grouped_counts.reset_index(name='Count')
print(df_counts)
# Out:
#                        source_file  Count
# 0  per_annotator_training_data.csv     12
# 1     zenodo_release_data_2024.csv  15650

# %%
df_same_lang.dropna(subset = ['content_similarity'], inplace = True)
